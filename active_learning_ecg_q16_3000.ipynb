# %%
# %%capture
from source.active_learning.active_learning_ecg import *

# %%
# prepare data
es = ECGStream.from_(CSN2022)
es = es.shuffle()
num_max = (len(es))
es1000 = es.sub_es(range(min(3000, num_max)))
es = es.shuffle()
es100 = es.sub_es(range(min(100, num_max)))

label_encoder = LabelEncoder(CSN2022_LABELS)
func_ecg2x = lambda ecg: ecg.data.T[:, 0].reshape((-1, 1))
func_ecg2y = lambda ecg: label_encoder.label2y_single(ecg.label, onehot=True) if ecg.label else np.zeros(len(CSN2022_LABELS))
digitizer = ESDigitizer(16, func_ecg2x, func_ecg2y)
train_gen = digitizer.digitize_es(es1000)
test_gen = digitizer.digitize_es(es100)
x_test, y_test = test_gen.to_xy()
data = train_gen, x_test, y_test

m = es1000[0].data.shape[1]
n = len(CSN2022_LABELS)
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]
# warning, large RAM consumption!
# 100%|██████████| 6/6 [00:03<00:00,  1.80it/s]

# %%
# get results of different AL method
acc_baseline = eval_prioritization_strategy(data, KerasRobustCNN3(m, 1, n), trivial_strategy)
acc_entropy = eval_prioritization_strategy(data, KerasRobustCNN3(m, 1, n), max_entropy_strategy)
acc_bt = eval_prioritization_strategy(data, KerasRobustCNN3(m, 1, n), least_margin_strategy)
acc_vr = eval_prioritization_strategy(data, KerasRobustCNN3(m, 1, n), least_confidence_strategy)
# Out:
# Training data size of 16 => accuracy 0.000000
# Training data size of 32 => accuracy 0.000000
# Training data size of 48 => accuracy 0.177083
# Training data size of 64 => accuracy 0.156250
# Training data size of 80 => accuracy 0.031250
# Training data size of 96 => accuracy 0.135417
# Training data size of 112 => accuracy 0.281250
# Training data size of 128 => accuracy 0.354167
# Training data size of 144 => accuracy 0.364583
# Training data size of 160 => accuracy 0.406250
# Training data size of 176 => accuracy 0.354167
# Training data size of 192 => accuracy 0.406250
# Training data size of 208 => accuracy 0.406250
# Training data size of 224 => accuracy 0.385417
# Training data size of 240 => accuracy 0.395833
# Training data size of 256 => accuracy 0.385417
# Training data size of 272 => accuracy 0.395833
# Training data size of 288 => accuracy 0.416667
# Training data size of 304 => accuracy 0.416667
# Training data size of 320 => accuracy 0.406250
# Training data size of 336 => accuracy 0.395833
# Training data size of 352 => accuracy 0.489583
# Training data size of 368 => accuracy 0.552083
# Training data size of 384 => accuracy 0.677083
# Training data size of 400 => accuracy 0.718750
# Training data size of 416 => accuracy 0.552083
# Training data size of 432 => accuracy 0.729167
# Training data size of 448 => accuracy 0.750000
# Training data size of 464 => accuracy 0.708333
# Training data size of 480 => accuracy 0.739583
# Training data size of 496 => accuracy 0.718750
# Training data size of 512 => accuracy 0.739583
# Training data size of 528 => accuracy 0.750000
# Training data size of 544 => accuracy 0.739583
# Training data size of 560 => accuracy 0.708333
# Training data size of 576 => accuracy 0.770833
# Training data size of 592 => accuracy 0.750000
# Training data size of 608 => accuracy 0.750000
# Training data size of 624 => accuracy 0.760417
# Training data size of 640 => accuracy 0.760417
# - finished -
# Training data size of 16 => accuracy 0.187500
# Training data size of 32 => accuracy 0.187500
# Training data size of 48 => accuracy 0.187500
# Training data size of 64 => accuracy 0.187500
# Training data size of 80 => accuracy 0.177083
# Training data size of 96 => accuracy 0.135417
# Training data size of 112 => accuracy 0.312500
# Training data size of 128 => accuracy 0.395833
# Training data size of 144 => accuracy 0.364583
# Training data size of 160 => accuracy 0.343750
# Training data size of 176 => accuracy 0.354167
# Training data size of 192 => accuracy 0.354167
# Training data size of 208 => accuracy 0.343750
# Training data size of 224 => accuracy 0.354167
# Training data size of 240 => accuracy 0.354167
# Training data size of 256 => accuracy 0.364583
# Training data size of 272 => accuracy 0.364583
# Training data size of 288 => accuracy 0.364583
# Training data size of 304 => accuracy 0.427083
# Training data size of 320 => accuracy 0.458333
# Training data size of 336 => accuracy 0.520833
# Training data size of 352 => accuracy 0.541667
# Training data size of 368 => accuracy 0.593750
# Training data size of 384 => accuracy 0.635417
# Training data size of 400 => accuracy 0.708333
# Training data size of 416 => accuracy 0.604167
# Training data size of 432 => accuracy 0.729167
# Training data size of 448 => accuracy 0.729167
# Training data size of 464 => accuracy 0.729167
# Training data size of 480 => accuracy 0.750000
# Training data size of 496 => accuracy 0.739583
# Training data size of 512 => accuracy 0.593750
# Training data size of 528 => accuracy 0.739583
# Training data size of 544 => accuracy 0.718750
# Training data size of 560 => accuracy 0.760417
# Training data size of 576 => accuracy 0.635417
# Training data size of 592 => accuracy 0.770833
# Training data size of 608 => accuracy 0.770833
# Training data size of 624 => accuracy 0.770833
# Training data size of 640 => accuracy 0.760417
# - finished -
# Training data size of 16 => accuracy 0.010417
# Training data size of 32 => accuracy 0.010417
# Training data size of 48 => accuracy 0.187500
# Training data size of 64 => accuracy 0.197917
# Training data size of 80 => accuracy 0.197917
# Training data size of 96 => accuracy 0.218750
# Training data size of 112 => accuracy 0.395833
# Training data size of 128 => accuracy 0.385417
# Training data size of 144 => accuracy 0.375000
# Training data size of 160 => accuracy 0.406250
# Training data size of 176 => accuracy 0.427083
# Training data size of 192 => accuracy 0.437500
# Training data size of 208 => accuracy 0.395833
# Training data size of 224 => accuracy 0.375000
# Training data size of 240 => accuracy 0.375000
# Training data size of 256 => accuracy 0.375000
# Training data size of 272 => accuracy 0.364583
# Training data size of 288 => accuracy 0.364583
# Training data size of 304 => accuracy 0.364583
# Training data size of 320 => accuracy 0.375000
# Training data size of 336 => accuracy 0.458333
# Training data size of 352 => accuracy 0.500000
# Training data size of 368 => accuracy 0.614583
# Training data size of 384 => accuracy 0.697917
# Training data size of 400 => accuracy 0.593750
# Training data size of 416 => accuracy 0.677083
# Training data size of 432 => accuracy 0.677083
# Training data size of 448 => accuracy 0.697917
# Training data size of 464 => accuracy 0.583333
# Training data size of 480 => accuracy 0.739583
# Training data size of 496 => accuracy 0.760417
# Training data size of 512 => accuracy 0.583333
# Training data size of 528 => accuracy 0.770833
# Training data size of 544 => accuracy 0.708333
# Training data size of 560 => accuracy 0.687500
# Training data size of 576 => accuracy 0.739583
# Training data size of 592 => accuracy 0.739583
# Training data size of 608 => accuracy 0.739583
# Training data size of 624 => accuracy 0.718750
# Training data size of 640 => accuracy 0.760417
# - finished -
# Training data size of 16 => accuracy 0.000000
# Training data size of 32 => accuracy 0.000000
# Training data size of 48 => accuracy 0.187500
# Training data size of 64 => accuracy 0.187500
# Training data size of 80 => accuracy 0.229167
# Training data size of 96 => accuracy 0.270833
# Training data size of 112 => accuracy 0.333333
# Training data size of 128 => accuracy 0.406250
# Training data size of 144 => accuracy 0.406250
# Training data size of 160 => accuracy 0.343750
# Training data size of 176 => accuracy 0.343750
# Training data size of 192 => accuracy 0.375000
# Training data size of 208 => accuracy 0.364583
# Training data size of 224 => accuracy 0.364583
# Training data size of 240 => accuracy 0.364583
# Training data size of 256 => accuracy 0.364583
# Training data size of 272 => accuracy 0.364583
# Training data size of 288 => accuracy 0.385417
# Training data size of 304 => accuracy 0.364583
# Training data size of 320 => accuracy 0.364583
# Training data size of 336 => accuracy 0.604167
# Training data size of 352 => accuracy 0.677083
# Training data size of 368 => accuracy 0.677083
# Training data size of 384 => accuracy 0.552083
# Training data size of 400 => accuracy 0.750000
# Training data size of 416 => accuracy 0.687500
# Training data size of 432 => accuracy 0.718750
# Training data size of 448 => accuracy 0.770833
# Training data size of 464 => accuracy 0.708333
# Training data size of 480 => accuracy 0.770833
# Training data size of 496 => accuracy 0.708333
# Training data size of 512 => accuracy 0.750000
# Training data size of 528 => accuracy 0.739583
# Training data size of 544 => accuracy 0.770833
# Training data size of 560 => accuracy 0.697917
# Training data size of 576 => accuracy 0.739583
# Training data size of 592 => accuracy 0.760417
# Training data size of 608 => accuracy 0.697917
# Training data size of 624 => accuracy 0.729167
# Training data size of 640 => accuracy 0.729167
# - finished -

# %%
# visualize the performance difference
plt.plot(acc_baseline, 'k', label='baseline')
plt.plot(acc_vr, 'b', label='least confidence')
plt.plot(acc_entropy, 'g', label='highest entropy')
plt.plot(acc_bt, 'r', label='least margin')
plt.legend()
