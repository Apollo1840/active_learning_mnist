# %%
# %%capture
from active_learning_mnist_visual import *

# %%
# prepare data
mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0
data = x_train, y_train, x_test, y_test

# %%
plot_prioritization_strategy(data, mlp_classifier(), trivial_strategy)
# Out:
# operating t-SNE ...
# t-SNE done
# > selected 100 data (0.01%)
# > selected 600 data (0.06%)
# > selected 1100 data (0.11%)
# > selected 1600 data (0.16%)
# > selected 2100 data (0.21%)
# > selected 2600 data (0.26%)
# > selected 3100 data (0.31%)
# > selected 3600 data (0.36%)
# > selected 4100 data (0.41%)
# > selected 4600 data (0.46%)
# - finished -

# %%
plot_prioritization_strategy(data, mlp_classifier(), max_entropy_strategy)
# Out:
# operating t-SNE ...
# t-SNE done
# > selected 100 data (0.01%)
# > selected 600 data (0.06%)
# > selected 1100 data (0.11%)
# > selected 1600 data (0.16%)
# > selected 2100 data (0.21%)
# > selected 2600 data (0.26%)
# /home/congyu/congyu_program/pythons/inits/k_active_learning/active_learning_mnist.py:63: RuntimeWarning: divide by zero encountered in log
#   p = predictions * np.log(predictions)
# /home/congyu/congyu_program/pythons/inits/k_active_learning/active_learning_mnist.py:63: RuntimeWarning: invalid value encountered in multiply
#   p = predictions * np.log(predictions)
# > selected 3100 data (0.31%)
# /home/congyu/congyu_program/pythons/inits/k_active_learning/active_learning_mnist.py:63: RuntimeWarning: divide by zero encountered in log
#   p = predictions * np.log(predictions)
# /home/congyu/congyu_program/pythons/inits/k_active_learning/active_learning_mnist.py:63: RuntimeWarning: invalid value encountered in multiply
#   p = predictions * np.log(predictions)
# > selected 3600 data (0.36%)
# /home/congyu/congyu_program/pythons/inits/k_active_learning/active_learning_mnist.py:63: RuntimeWarning: divide by zero encountered in log
#   p = predictions * np.log(predictions)
# /home/congyu/congyu_program/pythons/inits/k_active_learning/active_learning_mnist.py:63: RuntimeWarning: invalid value encountered in multiply
#   p = predictions * np.log(predictions)
# > selected 4100 data (0.41%)
# /home/congyu/congyu_program/pythons/inits/k_active_learning/active_learning_mnist.py:63: RuntimeWarning: divide by zero encountered in log
#   p = predictions * np.log(predictions)
# /home/congyu/congyu_program/pythons/inits/k_active_learning/active_learning_mnist.py:63: RuntimeWarning: invalid value encountered in multiply
#   p = predictions * np.log(predictions)
# > selected 4600 data (0.46%)
# /home/congyu/congyu_program/pythons/inits/k_active_learning/active_learning_mnist.py:63: RuntimeWarning: divide by zero encountered in log
#   p = predictions * np.log(predictions)
# /home/congyu/congyu_program/pythons/inits/k_active_learning/active_learning_mnist.py:63: RuntimeWarning: invalid value encountered in multiply
#   p = predictions * np.log(predictions)
# - finished -
