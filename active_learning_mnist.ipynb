# %%
# %%capture
from active_learning_mnist import *

# %%
# prepare data
mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0
data = x_train, y_train, x_test, y_test

# %%
acc_baseline = eval_prioritization_strategy(data, mlp_classifier(), trivial_strategy)
acc_entropy = eval_prioritization_strategy(data, mlp_classifier(), max_entropy_strategy)
acc_bt = eval_prioritization_strategy(data, mlp_classifier(), least_margin_strategy)
acc_vr = eval_prioritization_strategy(data, mlp_classifier(), least_confidence_strategy)
# Out:
# Training data size of 500 => accuracy 0.831900
# Training data size of 1000 => accuracy 0.880100
# Training data size of 1500 => accuracy 0.892300
# Training data size of 2000 => accuracy 0.908500
# Training data size of 2500 => accuracy 0.918200
# Training data size of 3000 => accuracy 0.925200
# Training data size of 3500 => accuracy 0.933700
# Training data size of 4000 => accuracy 0.934000
# Training data size of 4500 => accuracy 0.941200
# Training data size of 5000 => accuracy 0.942200
# Training data size of 5500 => accuracy 0.944400
# Training data size of 6000 => accuracy 0.945800
# Training data size of 6500 => accuracy 0.946600
# Training data size of 7000 => accuracy 0.950100
# Training data size of 7500 => accuracy 0.953500
# Training data size of 8000 => accuracy 0.955300
# Training data size of 8500 => accuracy 0.955800
# Training data size of 9000 => accuracy 0.955700
# Training data size of 9500 => accuracy 0.956500
# Training data size of 10000 => accuracy 0.958700
# Training data size of 10500 => accuracy 0.958900
# Training data size of 11000 => accuracy 0.959700
# Training data size of 11500 => accuracy 0.962400
# Training data size of 12000 => accuracy 0.962800
# Training data size of 12500 => accuracy 0.964800
# Training data size of 13000 => accuracy 0.966700
# Training data size of 13500 => accuracy 0.965800
# Training data size of 14000 => accuracy 0.967100
# Training data size of 14500 => accuracy 0.969100
# Training data size of 15000 => accuracy 0.968600
# Training data size of 15500 => accuracy 0.969000
# Training data size of 16000 => accuracy 0.969700
# Training data size of 16500 => accuracy 0.969100
# Training data size of 17000 => accuracy 0.971600
# Training data size of 17500 => accuracy 0.971000
# Training data size of 18000 => accuracy 0.972200
# Training data size of 18500 => accuracy 0.971000
# Training data size of 19000 => accuracy 0.971600
# Training data size of 19500 => accuracy 0.972300
# Training data size of 20000 => accuracy 0.972000
# - finished -
# Training data size of 500 => accuracy 0.821800
# Training data size of 1000 => accuracy 0.855200
# Training data size of 1500 => accuracy 0.878200
# Training data size of 2000 => accuracy 0.906600
# Training data size of 2500 => accuracy 0.919900
# Training data size of 3000 => accuracy 0.939200
# Training data size of 3500 => accuracy 0.949800
# Training data size of 4000 => accuracy 0.958900
# Training data size of 4500 => accuracy 0.961800
# Training data size of 5000 => accuracy 0.968100
# Training data size of 5500 => accuracy 0.972900
# Training data size of 6000 => accuracy 0.974000
# Training data size of 6500 => accuracy 0.976100
# Training data size of 7000 => accuracy 0.975900
# Training data size of 7500 => accuracy 0.976300
# Training data size of 8000 => accuracy 0.976900
# Training data size of 8500 => accuracy 0.978200
# Training data size of 9000 => accuracy 0.977100
# Training data size of 9500 => accuracy 0.976900
# Training data size of 10000 => accuracy 0.977300
# Training data size of 10500 => accuracy 0.977300
# Training data size of 11000 => accuracy 0.977900
# Training data size of 11500 => accuracy 0.976900
# Training data size of 12000 => accuracy 0.977400
# Training data size of 12500 => accuracy 0.976300
# Training data size of 13000 => accuracy 0.977100
# Training data size of 13500 => accuracy 0.977900
# Training data size of 14000 => accuracy 0.977300
# Training data size of 14500 => accuracy 0.978700
# Training data size of 15000 => accuracy 0.978100
# Training data size of 15500 => accuracy 0.977700
# Training data size of 16000 => accuracy 0.977800
# Training data size of 16500 => accuracy 0.978400
# Training data size of 17000 => accuracy 0.978700
# Training data size of 17500 => accuracy 0.978200
# Training data size of 18000 => accuracy 0.978600
# Training data size of 18500 => accuracy 0.979000
# Training data size of 19000 => accuracy 0.980000
# Training data size of 19500 => accuracy 0.979200
# Training data size of 20000 => accuracy 0.978900
# - finished -
# Training data size of 500 => accuracy 0.826600
# Training data size of 1000 => accuracy 0.901000
# Training data size of 1500 => accuracy 0.924200
# Training data size of 2000 => accuracy 0.938800
# Training data size of 2500 => accuracy 0.951500
# Training data size of 3000 => accuracy 0.959300
# Training data size of 3500 => accuracy 0.966400
# Training data size of 4000 => accuracy 0.970500
# Training data size of 4500 => accuracy 0.973000
# Training data size of 5000 => accuracy 0.975200
# Training data size of 5500 => accuracy 0.977200
# Training data size of 6000 => accuracy 0.976700
# Training data size of 6500 => accuracy 0.979500
# Training data size of 7000 => accuracy 0.979000
# Training data size of 7500 => accuracy 0.980100
# Training data size of 8000 => accuracy 0.980500
# Training data size of 8500 => accuracy 0.980500
# Training data size of 9000 => accuracy 0.981700
# Training data size of 9500 => accuracy 0.980300
# Training data size of 10000 => accuracy 0.981300
# Training data size of 10500 => accuracy 0.980700
# Training data size of 11000 => accuracy 0.981300
# Training data size of 11500 => accuracy 0.981000
# Training data size of 12000 => accuracy 0.980800
# Training data size of 12500 => accuracy 0.980500
# Training data size of 13000 => accuracy 0.980700
# Training data size of 13500 => accuracy 0.980800
# Training data size of 14000 => accuracy 0.980400
# Training data size of 14500 => accuracy 0.981600
# Training data size of 15000 => accuracy 0.980700
# Training data size of 15500 => accuracy 0.981000
# Training data size of 16000 => accuracy 0.981100
# Training data size of 16500 => accuracy 0.980900
# Training data size of 17000 => accuracy 0.980400
# Training data size of 17500 => accuracy 0.980900
# Training data size of 18000 => accuracy 0.980400
# Training data size of 18500 => accuracy 0.979200
# Training data size of 19000 => accuracy 0.978100
# Training data size of 19500 => accuracy 0.980900
# Training data size of 20000 => accuracy 0.981400
# - finished -
# Training data size of 500 => accuracy 0.817200
# Training data size of 1000 => accuracy 0.874300
# Training data size of 1500 => accuracy 0.900800
# Training data size of 2000 => accuracy 0.920300
# Training data size of 2500 => accuracy 0.934000
# Training data size of 3000 => accuracy 0.950300
# Training data size of 3500 => accuracy 0.957900
# Training data size of 4000 => accuracy 0.965600
# Training data size of 4500 => accuracy 0.968900
# Training data size of 5000 => accuracy 0.971200
# Training data size of 5500 => accuracy 0.974300
# Training data size of 6000 => accuracy 0.976300
# Training data size of 6500 => accuracy 0.977300
# Training data size of 7000 => accuracy 0.979100
# Training data size of 7500 => accuracy 0.977500
# Training data size of 8000 => accuracy 0.978800
# Training data size of 8500 => accuracy 0.979100
# Training data size of 9000 => accuracy 0.979400
# Training data size of 9500 => accuracy 0.979100
# Training data size of 10000 => accuracy 0.979200
# Training data size of 10500 => accuracy 0.978800
# Training data size of 11000 => accuracy 0.979600
# Training data size of 11500 => accuracy 0.979900
# Training data size of 12000 => accuracy 0.979800
# Training data size of 12500 => accuracy 0.979500
# Training data size of 13000 => accuracy 0.979300
# Training data size of 13500 => accuracy 0.979200
# Training data size of 14000 => accuracy 0.978700
# Training data size of 14500 => accuracy 0.978000
# Training data size of 15000 => accuracy 0.979000
# Training data size of 15500 => accuracy 0.979500
# Training data size of 16000 => accuracy 0.979500
# Training data size of 16500 => accuracy 0.979300
# Training data size of 17000 => accuracy 0.977900
# Training data size of 17500 => accuracy 0.977700
# Training data size of 18000 => accuracy 0.977800
# Training data size of 18500 => accuracy 0.978800
# Training data size of 19000 => accuracy 0.978500
# Training data size of 19500 => accuracy 0.979300
# Training data size of 20000 => accuracy 0.980400
# - finished -

# %%
# visualize the performance difference
plt.plot(acc_baseline, 'k', label='baseline')
plt.plot(acc_entropy, 'b', label='least confidence')
plt.plot(acc_bt, 'g', label='highest entropy')
plt.plot(acc_vr, 'r', label='least margin')
plt.legend()
